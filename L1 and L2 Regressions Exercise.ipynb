# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('https://raw.githubusercontent.com/erkansirin78/datasets/master/Melbourne_housing_FULL.csv')

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
col_use = ['Suburb','Rooms','Type','Method','SellerG','Regionname','Propertycount',
       'Distance','CouncilArea', 'Bedroom2','Bathroom','Car',
       'Landsize','BuildingArea','Price']

# %%
df = df[col_use]
df
# Out:
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 0      Abbotsford      2    h     SS         Jellis  Northern Metropolitan
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 3      Abbotsford      3    u     VB         Rounds  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
# ...

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
cols_to_fill_zero = ['Propertycount','Distance','Bedroom2','Bathroom','Car']

# %%
df[cols_to_fill_zero] = df[cols_to_fill_zero].fillna(0)

# %%
df['Landsize'] = df['Landsize'].fillna(df.Landsize.mean())
df['BuildingArea'] = df['BuildingArea'].fillna(df.BuildingArea.mean())

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
#Dummy Encoding

df = pd.get_dummies(df, drop_first = True)
df.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price  Suburb_Aberfeldie  ...  \
# 1      160.2564  1480000.0                  0  ...
# 2       79.0000  1035000.0                  0  ...
# 4      150.0000  1465000.0                  0  ...
# 5      160.2564   850000.0                  0  ...
# 6      142.0000  1600000.0                  0  ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 1                                    0                                  0
# 2                                    0                                  0
# ...

# %%
X = df.drop('Price',axis = 1)
y = df['Price']

# %%
# Out:
# 1        1480000.0
# 2        1035000.0
# 4        1465000.0
# 5         850000.0
# 6        1600000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 27244, dtype: float64

# %%
#train_test_split

train_X,test_X,train_y,test_y = train_test_split(X,y, test_size  = 0.2, random_state = 2)

# %%
#Linear Regression

reg = LinearRegression()

reg.fit(train_X,train_y)
# Out:
# LinearRegression()

# %%
r_score_test = reg.score(test_X,test_y)
r_score_train = reg.score(train_X,train_y)
print(f'Regression Test Data Score :{r_score_test} \nLasso Reg Train Data Score :{r_score_train}')
# Out:
# Regression Test Data Score :0.6748321429523771
# Lasso Reg Train Data Score :0.6792421760392956

# %%
reg.intercept_
# Out:
# 796695.4844879601

# %%
reg.predict(test_X)
# Out:
# array([1702479.04385336, 1076331.60849396,  921498.34202843, ...,
#        1282304.43964138,  714017.37097934, 1226722.08721991])

# %%
#Tuning the model with Lasso Regression Method

from sklearn import linear_model 

lasso_reg = linear_model.Lasso(alpha=0.0001 , max_iter= 3000)

lasso_reg.fit(train_X,train_y)
# Out:
# Lasso(alpha=0.0001, max_iter=3000)

# %%
l_score_test = lasso_reg.score(test_X,test_y)
l_score_train = lasso_reg.score(train_X,train_y)
print(f'Lasso Reg Test Data Score :{l_score_test} \nLasso Reg Train Data Score :{l_score_train}')
# Out:
# Lasso Reg Test Data Score :0.6740291847701786
# Lasso Reg Train Data Score :0.6792421017965748

# %%
#Tuning the model with Ridge Regression Method

from sklearn.linear_model import Ridge

ridge_reg = linear_model.Ridge(alpha = 0.0001, max_iter=1000, tol=0.0001)

ridge_reg.fit(train_X,train_y)
# Out:
# Ridge(alpha=0.0001, max_iter=1000, tol=0.0001)

# %%
rg_score_test = ridge_reg.score(test_X,test_y)
rg_score_train = ridge_reg.score(train_X,train_y)
print(f'Lasso Reg Test Data Score :{rg_score_test} \nLasso Reg Train Data Score :{rg_score_train}')
# Out:
# Lasso Reg Test Data Score :0.6748333099258041
# Lasso Reg Train Data Score :0.6792421758879779
